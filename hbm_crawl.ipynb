# %% [markdown]
# # 'Human Brain Mapping' Journal Analysis

# %% [markdown]
# This notebook crawls 'Human brain mapping' articles and construct a knowledge graph based on these articles.
#
# Import libraries

# %%
import os
import sys
import time

import bs4
import mechanicalsoup
import pandas as pd
import progressbar
import requests
import scrapy
import tqdm
from bs4 import BeautifulSoup
from scrapy.linkextractors import LinkExtractor
from scrapy.spiders import CrawlSpider, Rule
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains

sys.path.append(
    os.path.join(
        os.path.abspath(""),
        "../../../work/git_repos/EMA/equipment-advisor-diagnosis-model-generation/utils",
    )
)

# %%
from util import getlog

logger = getlog(
    "humanBrainMapping", dir=os.path.join(os.path.abspath("")), level="DEBUG"
)

# %% [markdown]
# Download full texts of 'Human Brain Mapping' articles from [this link](https://www.ncbi.nlm.nih.gov/pmc/journals/3754/)

# %%
def getFullTextHBM(htmlFile, domain="https://www.ncbi.nlm.nih.gov"):
    """function for downloading full texts of HBM"""
    with open(os.path.join(os.path.abspath(""), htmlFile,), "r",) as f:
        soup = BeautifulSoup(f, "html.parser")
    allissues = soup.find_all("a", class_="arc-issue")

    issuesMetadata = []
    barall = progressbar.ProgressBar(len(allissues[:90]))  # recent 5 years issues
    barall.start()
    for i1 in range(len(allissues[:90])):
        i = allissues[i1]
        meta = dict()
        browser = webdriver.Chrome(
            os.path.join(
                os.path.abspath(""),
                "../../../work/git_repos/EMA/equipment-advisor-diagnosis-model-generation/data/scrapingTools/chromedriver",
            )
        )
        browser.get(domain + i.attrs["href"])
        temp = browser.page_source
        so = BeautifulSoup(temp)
        browser.quit()
        allpapers = so.find_all("div", class_="rprt")
        meta["issue"] = i.contents[0]
        if not os.path.exists(
            os.path.join(os.path.abspath(""), "corpus", meta["issue"].strip(": "))
        ):
            os.makedirs(
                os.path.join(os.path.abspath(""), "corpus", meta["issue"].strip(": "))
            )
        meta["url"] = domain + i.attrs["href"]
        meta["time"] = str(i).split("<br/>")[1].strip("</a>")
        meta["articles"] = []
        logger.info("downloading issue " + meta["issue"])
        logger.info(meta)
        bar = progressbar.ProgressBar(len(allpapers))
        bar.start()
        chrome_options = Options()
        chrome_options.add_experimental_option(
            "prefs",
            {
                "download.default_directory": os.path.join(
                    os.path.abspath(""), "corpus", meta["issue"].strip(": ")
                ),
                "download.prompt_for_download": False,
                "download.directory_upgrade": True,
                "plugins.always_open_pdf_externally": True,
            },
        )
        browser1 = webdriver.Chrome(
            os.path.join(
                os.path.abspath(""),
                "../../../work/git_repos/EMA/equipment-advisor-diagnosis-model-generation/data/scrapingTools/chromedriver",
            ),
            options=chrome_options,
        )
        for a1 in range(len(allpapers)):
            a = allpapers[a1]
            pmeta = dict()
            try:
                pmeta["url"] = (
                    domain + a.find("div", class_="title").find_next().attrs["href"]
                )
                pmeta["pmc_id"] = a.find("dl", class_="rprtid").contents[1].contents[0]
                pmeta["title"] = a.find("div", class_="title").find_next().contents[0]
                pmeta["authors"] = (
                    a.find("div", class_="supp").find("div", class_="desc").contents[0]
                )
            except Exception as e:
                logger.error(str(e))
            meta["articles"].append(pmeta)
            try:
                alllinks = a.find("div", class_="links")
                for a in alllinks.find_all("a", class_="view"):
                    if a.contents[0].startswith("PDF"):  # pdf full text link
                        link = domain + a.attrs["href"]
                        if not os.path.exists(
                            os.path.join(
                                os.path.abspath(""),
                                "corpus",
                                meta["issue"].strip(": "),
                                link.split("/")[-1],
                            )
                        ):
                            logger.info("saving paper from " + str(link))
                            browser1.get(link)
                            while True:
                                time.sleep(1)
                                if os.path.exists(
                                    os.path.join(
                                        os.path.abspath(""),
                                        "corpus",
                                        meta["issue"].strip(": "),
                                        link.split("/")[-1],
                                    )
                                ):
                                    logger.info("saved paper")
                                    break
                        else:
                            logger.info("paper already exists in repo")
                            pass
            except Exception as e:
                logger.error("error occurred when downloading paper")
                logger.error(str(e))
            bar.update(a1)
        issuesMetadata.append(meta)
        time.sleep(30)  # wait for the last document to be downloaded
        browser1.quit()
        barall.update(i1)
    return issuesMetadata

# %%
s = getFullTextHBM("hbmissues.html")
# Out:
# [ 2020-08-09 16:34:59,130 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 34 INFO ] downloading issue v.41(1):
# [ 2020-08-09 16:34:59,131 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 35 INFO ] {'issue': 'v.41(1): ', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/issues/358883/', 'time': '2020 Jan', 'articles': []}
# [ 2020-08-09 16:35:01,263 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,267 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,271 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,276 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,281 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,286 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,291 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,295 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,300 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,304 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,307 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,311 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,315 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,318 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,321 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,324 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,327 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,330 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,334 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:01,337 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7268039/pdf/HBM-41-270.pdf
# [ 2020-08-09 16:35:10,771 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 97 INFO ] saved paper
# [ 2020-08-09 16:35:53,977 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 34 INFO ] downloading issue v.41(2):
# [ 2020-08-09 16:35:53,978 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 35 INFO ] {'issue': 'v.41(2): ', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/issues/358888/', 'time': '2020 Feb 1', 'articles': []}
# [ 2020-08-09 16:35:56,070 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,074 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,078 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,082 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,085 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,088 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,092 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,095 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,100 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,104 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,108 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,111 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,114 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,117 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,121 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,125 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,128 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,131 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,135 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:35:56,139 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7267957/pdf/HBM-41-561.pdf
# [ 2020-08-09 16:36:06,782 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 97 INFO ] saved paper
# [ 2020-08-09 16:36:50,365 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 34 INFO ] downloading issue v.41(3):
# [ 2020-08-09 16:36:50,366 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 35 INFO ] {'issue': 'v.41(3): ', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/issues/350690/', 'time': '2020 Feb 15', 'articles': []}
# [ 2020-08-09 16:36:52,474 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,479 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,484 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,489 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,494 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,499 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,503 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,508 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,512 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,516 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,521 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,525 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,529 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,534 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,537 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,542 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,546 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,551 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,554 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:36:52,557 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7267968/pdf/HBM-41-666.pdf
# [ 2020-08-09 16:37:09,038 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 97 INFO ] saved paper
# [ 2020-08-09 16:37:52,288 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 34 INFO ] downloading issue v.41(4):
# [ 2020-08-09 16:37:52,290 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 35 INFO ] {'issue': 'v.41(4): ', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/issues/358885/', 'time': '2020 Mar', 'articles': []}
# [ 2020-08-09 16:37:54,361 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:37:54,364 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:37:54,369 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:37:54,373 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:37:54,378 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:37:54,382 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:37:54,387 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7267915/pdf/HBM-41-928.pdf
# [ 2020-08-09 16:38:06,071 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 97 INFO ] saved paper
# [ 2020-08-09 16:38:06,073 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,075 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,078 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,080 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,083 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,086 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,088 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,090 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,093 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,097 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,099 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,102 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:06,105 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:48,415 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 34 INFO ] downloading issue v.41(5):
# [ 2020-08-09 16:38:48,417 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 35 INFO ] {'issue': 'v.41(5): ', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/issues/358882/', 'time': '2020 Apr 1', 'articles': []}
# [ 2020-08-09 16:38:50,330 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,334 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,338 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,342 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,347 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,351 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,354 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,358 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,363 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,369 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,373 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,377 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,382 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:38:50,386 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7268060/pdf/HBM-41-1296.pdf
# [ 2020-08-09 16:39:00,191 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 97 INFO ] saved paper
# [ 2020-08-09 16:39:00,195 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7267988/pdf/HBM-41-1309.pdf
# [ 2020-08-09 16:39:14,804 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 97 INFO ] saved paper
# [ 2020-08-09 16:39:14,806 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:39:14,809 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:39:14,811 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:39:14,814 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 100 INFO ] paper already exists in repo
# [ 2020-08-09 16:39:14,817 MainProcess <ipython-input-156-46aac1fbfe7e> getFullTextHBM 85 INFO ] saving paper from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7